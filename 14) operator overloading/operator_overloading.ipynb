# %%
# '+' performs numerical addition when both values are integers.
a = 20 
b = 20

# %%
print(a + b)    # Output: 40
# Out:
# 40

# %%
# '+' performs string concatenation when both values are strings.
a = "hello "
b = "world"

# %%
print(a + b)    # Output: hello world
# Out:
# hello world
